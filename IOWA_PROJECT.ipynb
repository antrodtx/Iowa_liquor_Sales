# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iowa = pd.read_csv("iowa.csv", dtype = {'Zip Code' : 'object', 'Item Number' : 'object', 'Category' : 'object', 'Vendor Number' : 'object'})
iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26592863 entries, 0 to 26592862
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   object
#  2   Store Number           int64
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               object
#  7   Store Location         object
#  8   County Number          float64
#  9   County                 object
#  10  Category               object
#  11  Category Name          object
#  12  Vendor Number          object
#  13  Vendor Name            object
#  14  Item Number            object
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      float64
#  19  State Bottle Retail    float64
#  20  Bottles Sold           int64
# ...

# %%
iowa.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name                Address  \
# 0                 JOHNCY'S LIQUOR STORE  585 HWY 965 STE D & E
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY     2827 HAMILTON BLVD
# 2            JEFF'S MARKET / BLUE GRASS        102, W MAYNE ST
# 3  FAREWAY STORES #153  /  W DES MOINES          329 GRAND AVE
# 4     HY-VEE FOOD STORE #1 / MASON CITY         2400 4TH ST SW
#
#               City Zip Code                       Store Location  \
# 0    NORTH LIBERTY    52317          POINT (-91.60761 41.738129)
# 1       SIOUX CITY    51104         POINT (-96.417783 42.519886)
# 2       BLUE GRASS    52726         POINT (-90.766126 41.509119)
# ...

# %%
iowa['County Number'] = pd.to_numeric(iowa['County Number'], errors = 'coerce')
# Out:
#    Invoice/Item Number        Date  Store Number  \
# 0      INV-11440700004  04/11/2018          5514
# 1      INV-11583000132  04/18/2018          2623
# 2      INV-11516100032  04/16/2018          4967
# 3      INV-11469500012  04/12/2018          5146
# 4      INV-11457200003  04/12/2018          2515
# 5      INV-11630600023  04/23/2018          5244
# 6      INV-11417500008  04/10/2018          3769
# 7      INV-11606400047  04/19/2018          2648
# 8      INV-11634800078  04/23/2018          5236
# 9      INV-11560500001  04/18/2018          3647
# 10     INV-11573200019  04/18/2018          5515
# 11     INV-11629700055  04/23/2018          2651
# 12     INV-11484500042  04/13/2018          5327
# 13     INV-11563100218  04/18/2018          2565
# 14     INV-11438900032  04/11/2018          5515
#
#                               Store Name                Address  \
# 0                  JOHNCY'S LIQUOR STORE  585 HWY 965 STE D & E
# ...

# %%
iowa['County Number'].value_counts(dropna = False)
# Out:
# 77.0    4459618
# NaN     2460020
# 57.0    2013416
# 82.0    1472224
# 7.0     1353303
#          ...
# 2.0       19865
# 93.0      18725
# 26.0      17960
# 80.0      16297
# 36.0       4310
# Name: County Number, Length: 100, dtype: int64

# %%
iowa[iowa['County Number'].isna()]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name Address City Zip Code  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA     NaN  NaN      NaN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA     NaN  NaN      NaN
# 84910     CASEY'S GENERAL STORE #1365 / PAULLINA     NaN  NaN      NaN
# ...

# %%
iowa
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 0            INV-11440700004  04/11/2018          5514
# 1            INV-11583000132  04/18/2018          2623
# 2            INV-11516100032  04/16/2018          4967
# 3            INV-11469500012  04/12/2018          5146
# 4            INV-11457200003  04/12/2018          2515
# ...                      ...         ...           ...
# 26592858     INV-11623600016  04/20/2018          5494
# 26592859     INV-11527700017  04/17/2018          4485
# 26592860     INV-11481100023  04/13/2018          4602
# 26592861     INV-11434500122  04/11/2018          4509
# 26592862     INV-11539400080  04/17/2018          2545
#
#                                     Store Name                Address  \
# 0                        JOHNCY'S LIQUOR STORE  585 HWY 965 STE D & E
# 1            HY-VEE FOOD STORE #4 / SIOUX CITY     2827 HAMILTON BLVD
# 2                   JEFF'S MARKET / BLUE GRASS        102, W MAYNE ST
# ...

# %%
iowa1 = iowa.drop(['Address', 'County Number', 'Volume Sold (Gallons)'], axis = 1)
iowa1.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name             City Zip Code  \
# 0                 JOHNCY'S LIQUOR STORE    NORTH LIBERTY    52317
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY       SIOUX CITY    51104
# 2            JEFF'S MARKET / BLUE GRASS       BLUE GRASS    52726
# 3  FAREWAY STORES #153  /  W DES MOINES  WEST DES MOINES    50265
# 4     HY-VEE FOOD STORE #1 / MASON CITY       MASON CITY    50401
#
#                         Store Location       County Category  \
# 0          POINT (-91.60761 41.738129)      JOHNSON  1031100
# 1         POINT (-96.417783 42.519886)     WOODBURY  1012300
# 2         POINT (-90.766126 41.509119)        SCOTT  1031200
# ...

# %%
iowa1[['Vendor Name', 'Vendor Number']]
# Out:
#                        Vendor Name Vendor Number
# 0         MCCORMICK DISTILLING CO.           300
# 1         WILLIAM GRANT & SONS INC           240
# 2                PHILLIPS BEVERAGE           380
# 3                PHILLIPS BEVERAGE           380
# 4         CONSTELLATION BRANDS INC           115
# ...                            ...           ...
# 26592858           JIM BEAM BRANDS           065
# 26592859     SAZERAC NORTH AMERICA           055
# 26592860           DIAGEO AMERICAS           260
# 26592861           DIAGEO AMERICAS           260
# 26592862  WILLIAM GRANT & SONS INC           240
#
# [26592863 rows x 2 columns]

# %%
iowa2 = iowa1.drop(['Pack', 'Bottle Volume (ml)'], axis = 1)
iowa2.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name             City Zip Code  \
# 0                 JOHNCY'S LIQUOR STORE    NORTH LIBERTY    52317
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY       SIOUX CITY    51104
# 2            JEFF'S MARKET / BLUE GRASS       BLUE GRASS    52726
# 3  FAREWAY STORES #153  /  W DES MOINES  WEST DES MOINES    50265
# 4     HY-VEE FOOD STORE #1 / MASON CITY       MASON CITY    50401
#
#                         Store Location       County Category  \
# 0          POINT (-91.60761 41.738129)      JOHNSON  1031100
# 1         POINT (-96.417783 42.519886)     WOODBURY  1012300
# 2         POINT (-90.766126 41.509119)        SCOTT  1031200
# ...

# %%
iowa2.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 iowa2.info()
#
# NameError: name 'iowa2' is not defined

# %%
#iowa2['City'] = iowa2['City'].fillna('PAULLINA')
#iowa2['Zip Code'] = iowa2['Zip Code'].fillna(51046)
#iowa2['County'] = iowa2['County'].fillna("O'Brien")
#iowa2[iowa2['County'].isna()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, Store Location, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters)]
# Index: []

# %%
iowa2.isna()
# Out:
#           Invoice/Item Number   Date  Store Number  Store Name   City  \
# 0                       False  False         False       False  False
# 1                       False  False         False       False  False
# 2                       False  False         False       False  False
# 3                       False  False         False       False  False
# 4                       False  False         False       False  False
# ...                       ...    ...           ...         ...    ...
# 26592858                False  False         False       False  False
# 26592859                False  False         False       False  False
# 26592860                False  False         False       False  False
# 26592861                False  False         False       False  False
# 26592862                False  False         False       False  False
#
#           Zip Code  Store Location  County  Category  Category Name  \
# ...

# %%
iowa2[iowa2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, Store Location, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters)]
# Index: []

# %%
iowa2['County'].value_counts(dropna = False)
# Out:
# POLK          4906060
# LINN          2208035
# SCOTT         1600672
# BLACK HAWK    1477835
# JOHNSON       1319887
#                ...
# WAYNE           20790
# DAVIS           19221
# RINGGOLD        17641
# FREMONT          6357
# EL PASO             2
# Name: County, Length: 101, dtype: int64

# %%
print(iowa2['Store Number'].value_counts()[4777])
# Out:
# 3441

# %%
county_sort = iowa1.sort_values('County')
print(county_sort)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 23416280     INV-02244300008  12/19/2016          4417
# 3647274         S19812100019  06/27/2014          4317
# 9429675      INV-14208100034  08/31/2018          3461
# 2688203         S28051500019  09/22/2015          4317
# 480333       INV-13007200027  06/29/2018          3461
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name        City Zip Code  \
# 23416280                    KUM & GO #76 / ADAIR       ADAIR    50002
# 3647274         FAREWAY STORES #941 / GREENFIELD  GREENFIELD    50849
# 9429675                  HOMETOWN FOODS / STUART      STUART    50250
# ...

# %%
store_sort = iowa1.sort_values('Store Number')
print(store_sort)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 6590730         S22751800069  12/04/2014          2106
# 6766516         S23034000004  12/18/2014          2106
# 4324191         S12384200059  05/23/2013          2106
# 3239433         S04684200080  03/22/2012          2106
# 10540829     INV-21720900048  09/05/2019          2106
# ...                      ...         ...           ...
# 11938602     INV-58773900055  05/24/2023         10217
# 11968388     INV-58932200043  05/31/2023         10217
# 11923635     INV-58773800014  05/24/2023         10217
# 11928186     INV-58773900084  05/24/2023         10217
# 11929140     INV-58773800072  05/24/2023         10217
#
#                                        Store Name         City Zip Code  \
# 6590730               HILLSTREET NEWS AND TOBACCO  CEDAR FALLS    50613
# 6766516               HILLSTREET NEWS AND TOBACCO  CEDAR FALLS    50613
# 4324191               HILLSTREET NEWS AND TOBACCO  CEDAR FALLS    50613
# ...

# %%
iowa1[iowa1['County'].isna()]

# %%
iowa1.loc[iowa1['Store Number'] == 4777, "County"] = 'PAULINNA'
iowa1[iowa1['County'].isna()]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 656157          S04829500028  04/02/2012          3782
# 663232          S25608300034  05/12/2015          4247
# 663448          S06345300020  07/02/2012          3782
# 663645          S13965900016  08/19/2013          3782
# 667757          S19337500002  06/03/2014          4247
# ...                      ...         ...           ...
# 26189512     INV-10210400009  02/05/2018          4000
# 26191574     INV-10273800002  02/08/2018          3420
# 26193269     INV-10273800003  02/08/2018          3420
# 26195556     INV-10273700013  02/08/2018          3420
# 26203913     INV-10210400004  02/05/2018          4000
#
#                                  Store Name        City Zip Code  \
# 656157            BENDER FOODS / GUTTENBERG  GUTTENBERG    52052
# 663232        FAREWAY STORES #879 / BELMOND     BELMOND    50421
# 663448            BENDER FOODS / GUTTENBERG  GUTTENBERG    52052
# ...

# %%
paulinna = iowa1[iowa1['Store Number'] == 4777]
print(paulinna)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name City Zip Code Store Location  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN            NaN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN            NaN
# ...

# %%
#iowa2['City'] = iowa2['City'].fillna('PAULLINA')
#iowa2['Zip Code'] = iowa2['Zip Code'].fillna(51046)
#iowa2['County'] = iowa2['County'].fillna("O'Brien")
#iowa2[iowa2['County'].isna()]
iowa2.loc[iowa2['Store Number'] == 4777, "County"] = "O'Brien"
#iowa1.loc[iowa1['Store Number'] == 4777, "Zip Code"] = '51046'
paulinna = iowa2[iowa2['Store Number'] == 4777]
print(paulinna)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name City Zip Code Store Location  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN            NaN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN            NaN
# ...

# %%
iowa2.loc[iowa2['Store Number'] == 4777, "City"] = 'PAULINNA'
paulinna2 = iowa2[iowa2['Store Number'] == 4777]
print(paulinna2)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name      City Zip Code  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA      NaN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA      NaN
# 84910     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA      NaN
# ...

# %%
iowa2.loc[iowa2['Store Number'] == 4777, "Zip Code"] = '51046'
paulinna3 = iowa2[iowa2['Store Number'] == 4777]
print(paulinna3)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name      City Zip Code  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# 84910     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# ...

# %%
iowa2.loc[iowa2['Store Number'] == 4777]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name      City Zip Code  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# 84910     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# ...

# %%
store_group = iowa2.groupby(['Store Number', 'Sale (Dollars)']).sum()
print(store_group)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 store_group = iowa2.groupby(['Store Number', 'Sale (Dollars)']).sum()
#       2 print(store_group)
#
# NameError: name 'iowa2' is not defined
