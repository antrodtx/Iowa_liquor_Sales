# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iowa = pd.read_csv("iowa.csv", dtype = {'Zip Code' : 'object', 'Item Number' : 'object', 'Category' : 'object', 'Vendor Number' : 'object'})
iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26592863 entries, 0 to 26592862
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   object
#  2   Store Number           int64
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               object
#  7   Store Location         object
#  8   County Number          float64
#  9   County                 object
#  10  Category               object
#  11  Category Name          object
#  12  Vendor Number          object
#  13  Vendor Name            object
#  14  Item Number            object
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      float64
#  19  State Bottle Retail    float64
#  20  Bottles Sold           int64
# ...

# %%
iowa.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name                Address  \
# 0                 JOHNCY'S LIQUOR STORE  585 HWY 965 STE D & E
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY     2827 HAMILTON BLVD
# 2            JEFF'S MARKET / BLUE GRASS        102, W MAYNE ST
# 3  FAREWAY STORES #153  /  W DES MOINES          329 GRAND AVE
# 4     HY-VEE FOOD STORE #1 / MASON CITY         2400 4TH ST SW
#
#               City Zip Code                       Store Location  \
# 0    NORTH LIBERTY    52317          POINT (-91.60761 41.738129)
# 1       SIOUX CITY    51104         POINT (-96.417783 42.519886)
# 2       BLUE GRASS    52726         POINT (-90.766126 41.509119)
# ...

# %%
iowa1 = iowa.drop(['Address', 'County Number', 'Volume Sold (Gallons)', 'Pack', 'Bottle Volume (ml)', 'Store Location'], axis = 1)
iowa1.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name             City Zip Code  \
# 0                 JOHNCY'S LIQUOR STORE    NORTH LIBERTY    52317
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY       SIOUX CITY    51104
# 2            JEFF'S MARKET / BLUE GRASS       BLUE GRASS    52726
# 3  FAREWAY STORES #153  /  W DES MOINES  WEST DES MOINES    50265
# 4     HY-VEE FOOD STORE #1 / MASON CITY       MASON CITY    50401
#
#         County Category            Category Name Vendor Number  \
# 0      JOHNSON  1031100          AMERICAN VODKAS           300
# 1     WOODBURY  1012300       SINGLE MALT SCOTCH           240
# 2        SCOTT  1031200  AMERICAN FLAVORED VODKA           380
# ...

# %%
iowa2 = iowa1
iowa2.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name             City Zip Code  \
# 0                 JOHNCY'S LIQUOR STORE    NORTH LIBERTY    52317
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY       SIOUX CITY    51104
# 2            JEFF'S MARKET / BLUE GRASS       BLUE GRASS    52726
# 3  FAREWAY STORES #153  /  W DES MOINES  WEST DES MOINES    50265
# 4     HY-VEE FOOD STORE #1 / MASON CITY       MASON CITY    50401
#
#         County Category            Category Name Vendor Number  \
# 0      JOHNSON  1031100          AMERICAN VODKAS           300
# 1     WOODBURY  1012300       SINGLE MALT SCOTCH           240
# 2        SCOTT  1031200  AMERICAN FLAVORED VODKA           380
# ...

# %%
iowa1[iowa1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters)]
# Index: []

# %%
iowa1.loc[iowa1['Store Number'] == 4777, "County"] = "O'BRIEN"
iowa1[iowa1['County'].isna()]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 656157          S04829500028  04/02/2012          3782
# 663232          S25608300034  05/12/2015          4247
# 663448          S06345300020  07/02/2012          3782
# 663645          S13965900016  08/19/2013          3782
# 667757          S19337500002  06/03/2014          4247
# ...                      ...         ...           ...
# 26189512     INV-10210400009  02/05/2018          4000
# 26191574     INV-10273800002  02/08/2018          3420
# 26193269     INV-10273800003  02/08/2018          3420
# 26195556     INV-10273700013  02/08/2018          3420
# 26203913     INV-10210400004  02/05/2018          4000
#
#                                  Store Name        City Zip Code County  \
# 656157            BENDER FOODS / GUTTENBERG  GUTTENBERG    52052    NaN
# 663232        FAREWAY STORES #879 / BELMOND     BELMOND    50421    NaN
# 663448            BENDER FOODS / GUTTENBERG  GUTTENBERG    52052    NaN
# ...

# %%
iowa1.loc[iowa1['Store Number'] == 4777]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name City Zip Code   County  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN  O'BRIEN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN  O'BRIEN
# 84910     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN  O'BRIEN
# ...

# %%
iowa1.loc[iowa1['Store Number'] == 4777, "City"] = 'PAULINNA'
iowa1.loc[iowa1['Store Number'] == 4777]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name      City Zip Code   County  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA      NaN  O'BRIEN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA      NaN  O'BRIEN
# ...

# %%
iowa1.loc[iowa1['Store Number'] == 4777, "Zip Code"] = '51046'
iowa1.loc[iowa1['Store Number'] == 4777]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name      City Zip Code   County  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046  O'BRIEN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046  O'BRIEN
# ...

# %%
iowa3 = iowa1
iowa3
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 0            INV-11440700004  04/11/2018          5514
# 1            INV-11583000132  04/18/2018          2623
# 2            INV-11516100032  04/16/2018          4967
# 3            INV-11469500012  04/12/2018          5146
# 4            INV-11457200003  04/12/2018          2515
# ...                      ...         ...           ...
# 26592858     INV-11623600016  04/20/2018          5494
# 26592859     INV-11527700017  04/17/2018          4485
# 26592860     INV-11481100023  04/13/2018          4602
# 26592861     INV-11434500122  04/11/2018          4509
# 26592862     INV-11539400080  04/17/2018          2545
#
#                                     Store Name              City Zip Code  \
# 0                        JOHNCY'S LIQUOR STORE     NORTH LIBERTY    52317
# 1            HY-VEE FOOD STORE #4 / SIOUX CITY        SIOUX CITY    51104
# 2                   JEFF'S MARKET / BLUE GRASS        BLUE GRASS    52726
# ...

# %%
iowa3[iowa3['City'].isna()]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 4337242      INV-05737200173  06/26/2017          2591
# 4337404      INV-06989900018  08/30/2017          2543
# 4338031      INV-02652200057  01/11/2017          2556
# 4340436      INV-03787100032  03/14/2017          5243
# 4341754      INV-06037000110  07/12/2017          2543
# ...                      ...         ...           ...
# 26189512     INV-10210400009  02/05/2018          4000
# 26191574     INV-10273800002  02/08/2018          3420
# 26193269     INV-10273800003  02/08/2018          3420
# 26195556     INV-10273700013  02/08/2018          3420
# 26203913     INV-10210400004  02/05/2018          4000
#
#                                      Store Name City Zip Code County Category  \
# 4337242      HY-VEE WINE AND SPIRITS / ATLANTIC  NaN      NaN    NaN  1062200
# 4337404          HY-VEE FOOD STORE #1 / OTTUMWA  NaN      NaN    NaN  1011200
# ...

# %%
#Fill in nulls for City from Store Name
iowa3['City_2'] = iowa3['City'].fillna(iowa3['Store Name'].apply(lambda x: x.split('/')[1] if '/' in x else x))

# %%
iowa3[iowa3['Store Number'] == 3420]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 469          INV-11591000002  04/19/2018          3420
# 732          INV-11590800004  04/19/2018          3420
# 1073         INV-11462400033  04/12/2018          3420
# 1863         INV-11462400043  04/12/2018          3420
# 2030         INV-11462400074  04/12/2018          3420
# ...                      ...         ...           ...
# 26591823     INV-11590800025  04/19/2018          3420
# 26592361     INV-11590800019  04/19/2018          3420
# 26592478     INV-11590800073  04/19/2018          3420
# 26592512     INV-11462300003  04/12/2018          3420
# 26592635     INV-11590800051  04/19/2018          3420
#
#                                  Store Name             City Zip Code County  \
# 469       SAM'S CLUB 6344 / WINDSOR HEIGHTS  WINDSOR HEIGHTS    50311   POLK
# 732       SAM'S CLUB 6344 / WINDSOR HEIGHTS  WINDSOR HEIGHTS    50311   POLK
# ...

# %%
iowa3[iowa3['City_2'].isna()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), City_2]
# Index: []

# %%
#Store Names with 2 '/' and City is null
iowa3[(iowa3['Store Name'].str.count('/') == 2) & (iowa3['City'].isna())]['Store Name'].unique()
#iowa3[(iowa3['Store Name'].str.count('/') == 2) & (iowa3['City'].isna())]
# Out:
# array(['NEW STAR / LAFAYETTE / WATERLOO'], dtype=object)

# %%
iowa3[iowa3['Invoice/Item Number'].isna()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), City_2]
# Index: []

# %%
#Total nulls in CATEGORY NAME
iowa3['Category Name'].isna().sum()
# Out:
# 25040

# %%
#List CATEGORY NAMES
iowa3['Category Name'].unique()
# Out:
# array(['AMERICAN VODKAS', 'SINGLE MALT SCOTCH', 'AMERICAN FLAVORED VODKA',
#        'CANADIAN WHISKIES', 'WHISKEY LIQUEUR',
#        'STRAIGHT BOURBON WHISKIES', '100% AGAVE TEQUILA',
#        'IMPORTED VODKAS', 'IMPORTED DRY GINS', 'GOLD RUM',
#        'AMERICAN BRANDIES', 'AMERICAN CORDIALS & LIQUEURS',
#        'CREAM LIQUEURS', 'SPICED RUM', 'TENNESSEE WHISKIES',
#        'AMERICAN DRY GINS', 'COCKTAILS/RTD', 'FLAVORED RUM',
#        'BLENDED WHISKIES', 'IMPORTED FLAVORED VODKA', 'IMPORTED BRANDIES',
#        'IMPORTED CORDIALS & LIQUEURS', 'WHITE RUM',
#        'TEMPORARY & SPECIALTY PACKAGES', 'IRISH WHISKIES',
#        'MIXTO TEQUILA', 'COFFEE LIQUEURS',
#        'AMERICAN DISTILLED SPIRITS SPECIALTY', 'NEUTRAL GRAIN SPIRITS',
#        'SCOTCH WHISKIES', 'SPECIAL ORDER ITEMS', 'AMERICAN SCHNAPPS',
#        'SINGLE BARREL BOURBON WHISKIES', 'IMPORTED SCHNAPPS',
#        'STRAIGHT RYE WHISKIES', 'NEUTRAL GRAIN SPIRITS FLAVORED',
# ...

# %%
#Groupby Category Name and Category
iowa3.groupby(['Category Name', 'Category']).count().index.tolist()
# Out:
# [('100 PROOF VODKA', '1031100'),
#  ('100% AGAVE TEQUILA', '1022200'),
#  ('AGED DARK RUM', '1062300'),
#  ('AMARETTO - IMPORTED', '1082010'),
#  ('AMERICAN ALCOHOL', '1101100'),
#  ('AMERICAN AMARETTO', '1081010'),
#  ('AMERICAN BRANDIES', '1051100'),
#  ('AMERICAN COCKTAILS', '1071100'),
#  ('AMERICAN CORDIALS & LIQUEURS', '1081000'),
#  ('AMERICAN CORDIALS & LIQUEURS', '1081300'),
#  ('AMERICAN DISTILLED SPIRITS SPECIALTY', '1091000'),
#  ('AMERICAN DISTILLED SPIRITS SPECIALTY', '1091100'),
#  ('AMERICAN DRY GINS', '1041100'),
#  ('AMERICAN FLAVORED VODKA', '1031200'),
#  ('AMERICAN GRAPE BRANDIES', '1051010'),
#  ('AMERICAN SCHNAPPS', '1081400'),
#  ('AMERICAN SLOE GINS', '1041200'),
#  ('AMERICAN SLOE GINS', '1041300'),
#  ('AMERICAN VODKAS', '1031000'),
#  ('AMERICAN VODKAS', '1031100'),
#  ('AMERICAN WHISKIES', '1011000'),
#  ('ANISETTE', '1081020'),
#  ('APPLE SCHNAPPS', '1081305'),
#  ('APRICOT BRANDIES', '1051100'),
#  ('BARBADOS RUM', '1062050'),
# ...

# %%
iowa3.loc[iowa3['Category Name'] == 'IRISH WHISKIES']
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 84           INV-11534700046  04/17/2018          3618
# 196          INV-11424900022  04/11/2018          3920
# 261          INV-11496300019  04/16/2018          4285
# 624          INV-11481600052  04/13/2018          2518
# 684          INV-11565900065  04/18/2018          2644
# ...                      ...         ...           ...
# 26592236     INV-11422000019  04/11/2018          3909
# 26592253     INV-11470100008  04/12/2018          4603
# 26592307     INV-11594700015  04/19/2018          4091
# 26592390     INV-11464400016  04/12/2018          4368
# 26592781     INV-11594600099  04/19/2018          4969
#
#                                            Store Name            City  \
# 84                       WAL-MART 2716 / CEDAR RAPIDS    CEDAR RAPIDS
# 196       SMOKIN' JOE'S #11 TOBACCO AND LIQUOR OUTLET         CLINTON
# 261                 FAREWAY STORES #922 / NEW HAMPTON     NEW HAMPTON
# ...

# %%
iowa3.loc[iowa3['Category Name'] == 'SINGLE MALT SCOTCH']
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 1            INV-11583000132  04/18/2018          2623
# 178          INV-11563300033  04/18/2018          3390
# 229          INV-11633300066  04/23/2018          3762
# 571          INV-11530000009  04/17/2018          2604
# 588          INV-11585800063  04/18/2018          2508
# ...                      ...         ...           ...
# 26592265     INV-11404900009  04/10/2018          2666
# 26592281     INV-11487400079  04/13/2018          3819
# 26592561     INV-11500500003  04/16/2018          2670
# 26592798     INV-11524700004  04/16/2018          2190
# 26592852     INV-11429100104  04/11/2018          2644
#
#                                    Store Name             City Zip Code  \
# 1           HY-VEE FOOD STORE #4 / SIOUX CITY       SIOUX CITY    51104
# 178                     OKOBOJI AVENUE LIQUOR          MILFORD    51351
# 229                  WINE AND SPIRITS GALLERY  WINDSOR HEIGHTS    50322
# ...

# %%
iowa3.loc[iowa3['Category'] == '1012210']
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 432485          S26009000179  06/03/2015          2614
# 443197          S13777200036  08/07/2013          3952
# 452214          S18666600018  04/29/2014          4895
# 606043          S09485000006  12/13/2012          2521
# 630621          S09756200052  12/28/2012          2532
# ...                      ...         ...           ...
# 21566142        S34091600002  08/24/2016          2543
# 21574560        S34156300061  08/26/2016          2585
# 21582057        S34158800069  08/26/2016          4478
# 25906252        S10069500080  01/16/2013          3990
# 25912940        S29139200002  11/18/2015          2576
#
#                                     Store Name             City Zip Code  \
# 432485            HY-VEE #3 FOOD AND DRUGSTORE        DAVENPORT    52807
# 443197                           LOT-A-SPIRITS       BETTENDORF    52722
# 452214                     BIG DISCOUNT LIQUOR     CEDAR RAPIDS    52402
# ...

# %%
iowa3[iowa3['Category Name'] == 'JAPANESE WHISKY']
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 1771112         S18362300002  04/10/2014          2190
# 1924132         S12294800003  05/20/2013          2512
# 2168814         S22395100007  11/17/2014          2190
# 2490979         S18354900001  04/09/2014          4129
# 3108643         S18362300003  04/10/2014          2190
# ...                      ...         ...           ...
# 21320381        S33607200107  07/27/2016          3869
# 21337859        S33578500030  07/26/2016          2285
# 21350353        S33575700011  07/27/2016          4129
# 21356275        S33575900006  07/27/2016          2614
# 21368614        S33612900043  07/27/2016          4509
#
#                                    Store Name        City Zip Code   County  \
# 1771112             CENTRAL CITY LIQUOR, INC.  DES MOINES    50314     POLK
# 1924132   HY-VEE WINE AND SPIRITS / IOWA CITY   IOWA CITY    52240  JOHNSON
# ...

# %%
iowa3.loc[iowa3['Category'] == '1012400']
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 84           INV-11534700046  04/17/2018          3618
# 196          INV-11424900022  04/11/2018          3920
# 261          INV-11496300019  04/16/2018          4285
# 624          INV-11481600052  04/13/2018          2518
# 684          INV-11565900065  04/18/2018          2644
# ...                      ...         ...           ...
# 26592236     INV-11422000019  04/11/2018          3909
# 26592253     INV-11470100008  04/12/2018          4603
# 26592307     INV-11594700015  04/19/2018          4091
# 26592390     INV-11464400016  04/12/2018          4368
# 26592781     INV-11594600099  04/19/2018          4969
#
#                                            Store Name            City  \
# 84                       WAL-MART 2716 / CEDAR RAPIDS    CEDAR RAPIDS
# 196       SMOKIN' JOE'S #11 TOBACCO AND LIQUOR OUTLET         CLINTON
# 261                 FAREWAY STORES #922 / NEW HAMPTON     NEW HAMPTON
# ...

# %%
#change the category # for Japanese Whisky to 1012450
iowa3.loc[iowa3['Category Name'] == 'JAPANESE WHISKY', 'Category'] = '1012450'

# %%
iowa3.loc[iowa3['Category Name'] == 'JAPANESE WHISKY']
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 1771112         S18362300002  04/10/2014          2190
# 1924132         S12294800003  05/20/2013          2512
# 2168814         S22395100007  11/17/2014          2190
# 2490979         S18354900001  04/09/2014          4129
# 3108643         S18362300003  04/10/2014          2190
# ...                      ...         ...           ...
# 21320381        S33607200107  07/27/2016          3869
# 21337859        S33578500030  07/26/2016          2285
# 21350353        S33575700011  07/27/2016          4129
# 21356275        S33575900006  07/27/2016          2614
# 21368614        S33612900043  07/27/2016          4509
#
#                                    Store Name        City Zip Code   County  \
# 1771112             CENTRAL CITY LIQUOR, INC.  DES MOINES    50314     POLK
# 1924132   HY-VEE WINE AND SPIRITS / IOWA CITY   IOWA CITY    52240  JOHNSON
# ...

# %%
cty = pd.read_excel("IowaCity_County.xlsx", sheet_name = 'Category Names(CLEAN)')
cty.head()
# Out:
#    Category                   Category Name
# 0   1011000               AMERICAN WHISKIES
# 1   1011100                BLENDED WHISKIES
# 2   1011200       STRAIGHT BOURBON WHISKIES
# 3   1011250  SINGLE BARREL BOURBON WHISKIES
# 4   1011300              TENNESSEE WHISKIES

# %%
cty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       111 non-null    int64
#  1   Category Name  111 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 1.9+ KB

# %%
iowa4 = iowa3
iowa4
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 0            INV-11440700004  04/11/2018          5514
# 1            INV-11583000132  04/18/2018          2623
# 2            INV-11516100032  04/16/2018          4967
# 3            INV-11469500012  04/12/2018          5146
# 4            INV-11457200003  04/12/2018          2515
# ...                      ...         ...           ...
# 26592858     INV-11623600016  04/20/2018          5494
# 26592859     INV-11527700017  04/17/2018          4485
# 26592860     INV-11481100023  04/13/2018          4602
# 26592861     INV-11434500122  04/11/2018          4509
# 26592862     INV-11539400080  04/17/2018          2545
#
#                                     Store Name              City Zip Code  \
# 0                        JOHNCY'S LIQUOR STORE     NORTH LIBERTY    52317
# 1            HY-VEE FOOD STORE #4 / SIOUX CITY        SIOUX CITY    51104
# 2                   JEFF'S MARKET / BLUE GRASS        BLUE GRASS    52726
# ...

# %%
iowa4[iowa4['Category Name'].isna()]['Category'].value_counts()
# Out:
# 1022200    2570
# 1052100    2315
# 1032100    1246
# 1082100     740
# 1062400     383
# 1062500     355
# 1091100     206
# 1082200     100
# 1091300      56
# 1011700      39
# 1092100      21
# 1062250      13
# 101220        6
# 1081100       6
# 1022300       5
# 1091200       4
# 1089290       1
# Name: Category, dtype: int64

# %%
iowa4[iowa4['Category'] == '1022200']
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 7            INV-11606400047  04/19/2018          2648
# 58           INV-11582700008  04/18/2018          4452
# 77           INV-11519500184  04/16/2018          2573
# 81           INV-11519100003  04/16/2018          4984
# 89           INV-11582900076  04/18/2018          5351
# ...                      ...         ...           ...
# 26592718     INV-11418400017  04/10/2018          4077
# 26592727     INV-11621700010  04/20/2018          5302
# 26592777     INV-11554900018  04/17/2018          5063
# 26592799     INV-11417700052  04/10/2018          2572
# 26592812     INV-11604900188  04/19/2018          2633
#
#                                Store Name             City Zip Code  \
# 7                         HY-VEE #4 / WDM  WEST DES MOINES    50265
# 58               SELECT MART    GORDON DR       SIOUX CITY    51105
# 77          HY-VEE FOOD STORE / MUSCATINE        MUSCATINE    52761
# ...

# %%
iowa4.loc[iowa4['Category'] == '1022200', 'Category Name'] = '100% AGAVE TEQUILA'

# %%
iowa4[iowa4['Category Name'].isna()]['Category'].value_counts()
# Out:
# 1052100    2315
# 1032100    1246
# 1082100     740
# 1062400     383
# 1062500     355
# 1091100     206
# 1082200     100
# 1091300      56
# 1011700      39
# 1092100      21
# 1062250      13
# 101220        6
# 1081100       6
# 1022300       5
# 1091200       4
# 1089290       1
# Name: Category, dtype: int64

# %%
iowa4.loc[iowa4['Category'] == '1052100', 'Category Name'] = 'IMPORTED BRANDIES'

# %%
iowa4.loc[iowa4['Category'] == '1032100', 'Category Name'] = 'IMPORTED VODKAS'

# %%
iowa4.loc[iowa4['Category'] == '1082100', 'Category Name'] = 'IMPORTED CORDIALS & LIQUEURS'

# %%
iowa4.loc[iowa4['Category'] == '1062400', 'Category Name'] = 'SPICED RUM'

# %%
iowa4.loc[iowa4['Category'] == '1062500', 'Category Name'] = 'FLAVORED RUM'

# %%
iowa4.loc[iowa4['Category'] == '1091100', 'Category Name'] = 'AMERICAN DISTILLED SPIRITS SPECIALTY'

# %%
iowa4.loc[iowa4['Category'] == '1082200', 'Category Name'] = 'IMPORTED SCHNAPPS'

# %%
iowa4.loc[iowa4['Category'] == '1091300', 'Category Name'] = 'NEUTRAL GRAIN SPIRITS FLAVORED'

# %%
iowa4[iowa4['Category Name'].isna()]['Category'].value_counts()
# Out:
# 1011700    39
# 1092100    21
# 1062250    13
# 101220      6
# 1081100     6
# 1022300     5
# 1091200     4
# 1089290     1
# Name: Category, dtype: int64

# %%
iowa4['Category Name'].value_counts(dropna = False)
# Out:
# CANADIAN WHISKIES                 2543345
# AMERICAN VODKAS                   2510723
# STRAIGHT BOURBON WHISKIES         1670522
# SPICED RUM                        1303258
# VODKA 80 PROOF                    1265974
#                                    ...
# IMPORTED GINS                          17
# IMPORTED VODKA - CHERRY                14
# IMPORTED WHISKIES                      12
# DELISTED / SPECIAL ORDER ITEMS          1
# AMERICAN WHISKIES                       1
# Name: Category Name, Length: 104, dtype: int64

# %%
iowa4[iowa4['Sale (Dollars)'].isna()]
# Out:
#         Invoice/Item Number        Date  Store Number  \
# 874030         S03816000008  01/30/2012          3583
# 1031042        S03816800149  01/30/2012          2190
# 1919126        S03842900093  01/31/2012          2614
# 1993924        S03839800115  01/31/2012          2593
# 2077479        S03825400160  01/31/2012          2616
# 2539535        S03818000080  01/31/2012          4509
# 3629257        S03842900089  01/31/2012          2614
# 4993614        S03841000063  01/31/2012          2549
# 5130273        S03831800099  01/31/2012          2629
# 6618202        S03814000102  01/30/2012          2623
#
#                                    Store Name            City Zip Code  \
# 874030                MAC'S LIQUOR AND VIDEOS         CORYDON    50060
# 1031042             CENTRAL CITY LIQUOR, INC.      DES MOINES    50314
# 1919126          HY-VEE #3 FOOD AND DRUGSTORE       DAVENPORT    52807
# 1993924           HY-VEE FOOD STORE / CARROLL         CARROLL    51401
# ...

# %%
iowa4[iowa4['Bottles Sold'].isna()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), City_2]
# Index: []

# %%
iowa4.to_csv('IOWA.csv')

# %%
#iowa4.to_csv('IOWA.csv')
