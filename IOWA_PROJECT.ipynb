# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iowa = pd.read_csv("iowa.csv", dtype = {'Zip Code' : 'object', 'Item Number' : 'object', 'Category' : 'object', 'Vendor Number' : 'object'})
iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26592863 entries, 0 to 26592862
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   object
#  2   Store Number           int64
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               object
#  7   Store Location         object
#  8   County Number          float64
#  9   County                 object
#  10  Category               object
#  11  Category Name          object
#  12  Vendor Number          object
#  13  Vendor Name            object
#  14  Item Number            object
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      float64
#  19  State Bottle Retail    float64
#  20  Bottles Sold           int64
# ...

# %%
iowa.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name                Address  \
# 0                 JOHNCY'S LIQUOR STORE  585 HWY 965 STE D & E
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY     2827 HAMILTON BLVD
# 2            JEFF'S MARKET / BLUE GRASS        102, W MAYNE ST
# 3  FAREWAY STORES #153  /  W DES MOINES          329 GRAND AVE
# 4     HY-VEE FOOD STORE #1 / MASON CITY         2400 4TH ST SW
#
#               City Zip Code                       Store Location  \
# 0    NORTH LIBERTY    52317          POINT (-91.60761 41.738129)
# 1       SIOUX CITY    51104         POINT (-96.417783 42.519886)
# 2       BLUE GRASS    52726         POINT (-90.766126 41.509119)
# ...

# %%
iowa1 = iowa.drop(['Address', 'County Number', 'Volume Sold (Gallons)', 'Pack', 'Bottle Volume (ml)'], axis = 1)
iowa1.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name             City Zip Code  \
# 0                 JOHNCY'S LIQUOR STORE    NORTH LIBERTY    52317
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY       SIOUX CITY    51104
# 2            JEFF'S MARKET / BLUE GRASS       BLUE GRASS    52726
# 3  FAREWAY STORES #153  /  W DES MOINES  WEST DES MOINES    50265
# 4     HY-VEE FOOD STORE #1 / MASON CITY       MASON CITY    50401
#
#                         Store Location       County Category  \
# 0          POINT (-91.60761 41.738129)      JOHNSON  1031100
# 1         POINT (-96.417783 42.519886)     WOODBURY  1012300
# 2         POINT (-90.766126 41.509119)        SCOTT  1031200
# ...

# %%
iowa2 = iowa1
iowa2.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-11440700004  04/11/2018          5514
# 1     INV-11583000132  04/18/2018          2623
# 2     INV-11516100032  04/16/2018          4967
# 3     INV-11469500012  04/12/2018          5146
# 4     INV-11457200003  04/12/2018          2515
#
#                              Store Name             City Zip Code  \
# 0                 JOHNCY'S LIQUOR STORE    NORTH LIBERTY    52317
# 1     HY-VEE FOOD STORE #4 / SIOUX CITY       SIOUX CITY    51104
# 2            JEFF'S MARKET / BLUE GRASS       BLUE GRASS    52726
# 3  FAREWAY STORES #153  /  W DES MOINES  WEST DES MOINES    50265
# 4     HY-VEE FOOD STORE #1 / MASON CITY       MASON CITY    50401
#
#                         Store Location       County Category  \
# 0          POINT (-91.60761 41.738129)      JOHNSON  1031100
# 1         POINT (-96.417783 42.519886)     WOODBURY  1012300
# 2         POINT (-90.766126 41.509119)        SCOTT  1031200
# ...

# %%
iowa1[iowa1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, Store Location, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters)]
# Index: []

# %%
#iowa1[iowa1['County'].isna()]

# %%
iowa1.loc[iowa1['Store Number'] == 4777, "County"] = "O'BRIEN"
iowa1[iowa1['County'].isna()]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 656157          S04829500028  04/02/2012          3782
# 663232          S25608300034  05/12/2015          4247
# 663448          S06345300020  07/02/2012          3782
# 663645          S13965900016  08/19/2013          3782
# 667757          S19337500002  06/03/2014          4247
# ...                      ...         ...           ...
# 26189512     INV-10210400009  02/05/2018          4000
# 26191574     INV-10273800002  02/08/2018          3420
# 26193269     INV-10273800003  02/08/2018          3420
# 26195556     INV-10273700013  02/08/2018          3420
# 26203913     INV-10210400004  02/05/2018          4000
#
#                                  Store Name        City Zip Code  \
# 656157            BENDER FOODS / GUTTENBERG  GUTTENBERG    52052
# 663232        FAREWAY STORES #879 / BELMOND     BELMOND    50421
# 663448            BENDER FOODS / GUTTENBERG  GUTTENBERG    52052
# ...

# %%
paulinna = iowa1[iowa1['Store Number'] == 4777]
print(paulinna)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name City Zip Code Store Location  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN            NaN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  NaN      NaN            NaN
# ...

# %%
iowa1.loc[iowa1['Store Number'] == 4777, "City"] = 'PAULINNA'
paulinna2 = iowa1[iowa1['Store Number'] == 4777]
print(paulinna2)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name      City Zip Code  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA      NaN
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA      NaN
# 84910     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA      NaN
# ...

# %%
iowa1.loc[iowa1['Store Number'] == 4777, "Zip Code"] = '51046'
paulinna3 = iowa1[iowa1['Store Number'] == 4777]
print(paulinna3)
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name      City Zip Code  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# 84910     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# ...

# %%
iowa1.loc[iowa1['Store Number'] == 4777]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 16796        INV-11832200022  05/01/2018          4777
# 78409        INV-11832200021  05/01/2018          4777
# 84910        INV-11832200012  05/01/2018          4777
# 85270        INV-11832200003  05/01/2018          4777
# 87391        INV-11832200001  05/01/2018          4777
# ...                      ...         ...           ...
# 26539746     INV-11288900008  04/03/2018          4777
# 26539959     INV-11288900017  04/03/2018          4777
# 26542633     INV-11288900015  04/03/2018          4777
# 26553855     INV-11288900007  04/03/2018          4777
# 26563008     INV-11288900005  04/03/2018          4777
#
#                                       Store Name      City Zip Code  \
# 16796     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# 78409     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# 84910     CASEY'S GENERAL STORE #1365 / PAULLINA  PAULINNA    51046
# ...

# %%
iowa3 = iowa1
iowa3
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 0            INV-11440700004  04/11/2018          5514
# 1            INV-11583000132  04/18/2018          2623
# 2            INV-11516100032  04/16/2018          4967
# 3            INV-11469500012  04/12/2018          5146
# 4            INV-11457200003  04/12/2018          2515
# ...                      ...         ...           ...
# 26592858     INV-11623600016  04/20/2018          5494
# 26592859     INV-11527700017  04/17/2018          4485
# 26592860     INV-11481100023  04/13/2018          4602
# 26592861     INV-11434500122  04/11/2018          4509
# 26592862     INV-11539400080  04/17/2018          2545
#
#                                     Store Name              City Zip Code  \
# 0                        JOHNCY'S LIQUOR STORE     NORTH LIBERTY    52317
# 1            HY-VEE FOOD STORE #4 / SIOUX CITY        SIOUX CITY    51104
# 2                   JEFF'S MARKET / BLUE GRASS        BLUE GRASS    52726
# ...

# %%
iowa3[iowa3['City'].isna()]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 4337242      INV-05737200173  06/26/2017          2591
# 4337404      INV-06989900018  08/30/2017          2543
# 4338031      INV-02652200057  01/11/2017          2556
# 4340436      INV-03787100032  03/14/2017          5243
# 4341754      INV-06037000110  07/12/2017          2543
# ...                      ...         ...           ...
# 26189512     INV-10210400009  02/05/2018          4000
# 26191574     INV-10273800002  02/08/2018          3420
# 26193269     INV-10273800003  02/08/2018          3420
# 26195556     INV-10273700013  02/08/2018          3420
# 26203913     INV-10210400004  02/05/2018          4000
#
#                                      Store Name City Zip Code Store Location  \
# 4337242      HY-VEE WINE AND SPIRITS / ATLANTIC  NaN      NaN            NaN
# 4337404          HY-VEE FOOD STORE #1 / OTTUMWA  NaN      NaN            NaN
# ...

# %%
#Fill in null City with City from [Store Name]
iowa3['City_2'] = iowa3['City'].fillna(iowa3['Store Name'].apply(lambda x: x.split('/')[1] if '/' in x else x))

# %%
iowa3[iowa3['City_2'].isna()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, Store Location, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), City_2]
# Index: []

# %%
#Store Name with 2 '/' in it and City is null
iowa3[(iowa3['Store Name'].str.count('/') == 2) & (iowa3['City'].isna())]
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 4340436      INV-03787100032  03/14/2017          5243
# 4346867      INV-02425400002  12/27/2016          5243
# 9344845      INV-03526300048  02/28/2017          5243
# 9352188      INV-01839600009  11/29/2016          5243
# 9362506      INV-04438900021  04/18/2017          5243
# ...                      ...         ...           ...
# 25562084     INV-00560300023  09/27/2016          5243
# 25563292     INV-00560300031  09/27/2016          5243
# 25563371     INV-00560300001  09/27/2016          5243
# 25563678     INV-00560300015  09/27/2016          5243
# 25563957     INV-00560300002  09/27/2016          5243
#
#                                Store Name City Zip Code Store Location County  \
# 4340436   NEW STAR / LAFAYETTE / WATERLOO  NaN      NaN            NaN    NaN
# 4346867   NEW STAR / LAFAYETTE / WATERLOO  NaN      NaN            NaN    NaN
# ...

# %%
iowa3[iowa3['Invoice/Item Number'].isna()]
# Out:
# Empty DataFrame
# Columns: [Invoice/Item Number, Date, Store Number, Store Name, City, Zip Code, Store Location, County, Category, Category Name, Vendor Number, Vendor Name, Item Number, Item Description, State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), City_2]
# Index: []
